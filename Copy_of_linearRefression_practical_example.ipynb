# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('/content/1.04. Real-life example.csv')

# %% [markdown]
# # **perprocessing**

# %%
data.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type Registration  Year         Model
# 0            BMW   4200.0      sedan      277      2.0      Petrol          yes  1991           320
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel          yes  1999  Sprinter 212
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas          yes  2003         S 500
# 3           Audi  23000.0  crossover      240      4.2      Petrol          yes  2007            Q7
# 4         Toyota  18300.0  crossover      120      2.0      Petrol          yes  2011         Rav 4

# %%
data.describe(include = 'all')
# Out:
#              Brand          Price   Body  ...  Registration         Year    Model
# count         4345    4173.000000   4345  ...          4345  4345.000000     4345
# unique           7            NaN      6  ...             2          NaN      312
# top     Volkswagen            NaN  sedan  ...           yes          NaN  E-Class
# freq           936            NaN   1649  ...          3947          NaN      199
# mean           NaN   19418.746935    NaN  ...           NaN  2006.550058      NaN
# std            NaN   25584.242620    NaN  ...           NaN     6.719097      NaN
# min            NaN     600.000000    NaN  ...           NaN  1969.000000      NaN
# 25%            NaN    6999.000000    NaN  ...           NaN  2003.000000      NaN
# 50%            NaN   11500.000000    NaN  ...           NaN  2008.000000      NaN
# 75%            NaN   21700.000000    NaN  ...           NaN  2012.000000      NaN
# ...

# %% [markdown]
# droppind model column as it have 312
# unique data which will aquire alot of dummys

# %%
data_without_model = data.drop(['Model'],axis = 1)

# %%
#checking for missing vaules
data_without_model.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %% [markdown]
# dropping null values

# %%
data_no_mv = data_without_model.dropna(axis = 0 )

# %% [markdown]
# looking at the price variable there is ouliers by observing min max mean 25% 50% 75% describtions

# %%
data_no_mv.describe(include = 'all')
# Out:
#              Brand          Price   Body  ...  Engine Type  Registration         Year
# count         4025    4025.000000   4025  ...         4025          4025  4025.000000
# unique           7            NaN      6  ...            4             2          NaN
# top     Volkswagen            NaN  sedan  ...       Diesel           yes          NaN
# freq           880            NaN   1534  ...         1861          3654          NaN
# mean           NaN   19552.308065    NaN  ...          NaN           NaN  2006.379627
# std            NaN   25815.734988    NaN  ...          NaN           NaN     6.695595
# min            NaN     600.000000    NaN  ...          NaN           NaN  1969.000000
# 25%            NaN    6999.000000    NaN  ...          NaN           NaN  2003.000000
# 50%            NaN   11500.000000    NaN  ...          NaN           NaN  2007.000000
# 75%            NaN   21900.000000    NaN  ...          NaN           NaN  2012.000000
# ...

# %% [markdown]
# print propability distribution function for each feature

# %%
sns.distplot(data_no_mv['Price'])
# Out:
# <ipython-input-39-14b257b4f014>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# **dealing with outliers**

# %%
q = data_no_mv['Price'].quantile(0.99)
data_1 = data_no_mv[data_no_mv['Price']<q]
data_1.describe(include ='all')
# Out:
#              Brand          Price   Body  ...  Engine Type  Registration         Year
# count         3984    3984.000000   3984  ...         3984          3984  3984.000000
# unique           7            NaN      6  ...            4             2          NaN
# top     Volkswagen            NaN  sedan  ...       Diesel           yes          NaN
# freq           880            NaN   1528  ...         1853          3613          NaN
# mean           NaN   17837.117460    NaN  ...          NaN           NaN  2006.292922
# std            NaN   18976.268315    NaN  ...          NaN           NaN     6.672745
# min            NaN     600.000000    NaN  ...          NaN           NaN  1969.000000
# 25%            NaN    6980.000000    NaN  ...          NaN           NaN  2002.750000
# 50%            NaN   11400.000000    NaN  ...          NaN           NaN  2007.000000
# 75%            NaN   21000.000000    NaN  ...          NaN           NaN  2011.000000
# ...

# %%
sns.distplot(data_1['Mileage'])
# Out:
# <ipython-input-41-eb5baa41d537>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
q = data_1['Mileage'].quantile(0.99)
data_1= data_1[data_1['Mileage']<q]
sns.distplot(data_1['Mileage'])
# Out:
# <ipython-input-43-b66f01775ec8>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
sns.distplot(data_1['EngineV'])
# Out:
# <ipython-input-44-d7e1a8aedfea>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %% [markdown]
# in EngineV they are labelling missing value with 99.99

# %%
data_3 = data_1[data_1['EngineV']<6.5]
sns.distplot(data_3['EngineV'])
# Out:
# <ipython-input-46-7cfb244dd805>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
sns.distplot(data_3['Year'])
# Out:
# <ipython-input-47-89784abcafb6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
q = data_3['Year'].quantile(0.01)
data_4 = data_3[data_3['Year']>q]
sns.distplot(data_4['Year'])
# Out:
# <ipython-input-48-a2fb60f6127b>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_4['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
data_cleaned = data_4.reset_index(drop = True)
data_cleaned.describe(include = 'all')
# Out:
#              Brand          Price   Body  ...  Engine Type  Registration         Year
# count         3867    3867.000000   3867  ...         3867          3867  3867.000000
# unique           7            NaN      6  ...            4             2          NaN
# top     Volkswagen            NaN  sedan  ...       Diesel           yes          NaN
# freq           848            NaN   1467  ...         1807          3505          NaN
# mean           NaN   18194.455679    NaN  ...          NaN           NaN  2006.709853
# std            NaN   19085.855165    NaN  ...          NaN           NaN     6.103870
# min            NaN     800.000000    NaN  ...          NaN           NaN  1988.000000
# 25%            NaN    7200.000000    NaN  ...          NaN           NaN  2003.000000
# 50%            NaN   11700.000000    NaN  ...          NaN           NaN  2008.000000
# 75%            NaN   21700.000000    NaN  ...          NaN           NaN  2012.000000
# ...

# %% [markdown]
# # **`Checkeing the OLS assumption`**

# %% [markdown]
# linearity

# %%
f, (ax1,ax2,ax3) = plt.subplots(1,3,sharey = True, figsize = (15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Price and Year')
ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])
ax2.set_title('EngineV and Price')
ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title('Mileage and Price')
plt.show()

# %%
sns.distplot(data_cleaned['Price'])
# Out:
# <ipython-input-55-f766034765e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_cleaned['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# since the price is non-linear so the relationship between it and the features is non-linear also ,
# so will use log transfrmation for price

# %%
log_price = np.log(data_cleaned['Price'])
data_cleaned['log_price'] = log_price
sns.distplot(data_cleaned['log_price'])
# Out:
# <ipython-input-54-fb03bccba9f7>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_cleaned['log_price'])
# <Axes: xlabel='log_price', ylabel='Density'>

# %% [markdown]
# plotting data with log_price

# %%
f, (ax1,ax2,ax3) = plt.subplots(1,3,sharey = True, figsize = (15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title('log_Price and Year')
ax2.scatter(data_cleaned['EngineV'],data_cleaned['log_price'])
ax2.set_title('EngineV and log_Price')
ax3.scatter(data_cleaned['Mileage'],data_cleaned['log_price'])
ax3.set_title('Mileage and log_Price')
plt.show()

# %%
data_cleaned = data_cleaned.drop(['Price'],axis = 1)

# %% [markdown]
# Multicollinearity

# %% [markdown]
# year and milage is highly correlated  as the car is old the milage increases

# %% [markdown]
# VIF is a way to check multicollinearity when f between 1 to 5 then there is no multicollinearity but there is no rule to it so it could be from 1 to 10 some timesin this example we will remove year only

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data_cleaned[['Mileage','Year','EngineV']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values,i) for i in range(variables.shape[1])]
vif['Features'] = variables.columns
vif
# Out:
#          VIF Features
# 0   3.791584  Mileage
# 1  10.354854     Year
# 2   7.662068  EngineV

# %%
data_cleaned = data_cleaned.drop(['Year'],axis = 1)

# %% [markdown]
# # **`create dummy variables`**

# %%
data_with_dummies = pd.get_dummies(data_cleaned,drop_first = True,dtype = int)
data_with_dummies.head()
# Out:
#    Mileage  EngineV  log_price  ...  Engine Type_Other  Engine Type_Petrol  Registration_yes
# 0      277      2.0   8.342840  ...                  0                   1                 1
# 1      427      2.9   8.974618  ...                  0                   0                 1
# 2      358      5.0   9.495519  ...                  0                   0                 1
# 3      240      4.2  10.043249  ...                  0                   1                 1
# 4      120      2.0   9.814656  ...                  0                   1                 1
#
# [5 rows x 18 columns]

# %% [markdown]
# rearranging data

# %%
data_with_dummies.columns.values
#
# Out:
# array(['Mileage', 'EngineV', 'log_price', 'Brand_BMW',
#        'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
#        'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
#        'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
#        'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes'],
#       dtype=object)

# %%
cols = [ 'log_price','EngineV', 'Mileage', 'Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']

# %%
data_preprocessed = data_with_dummies[cols]
data_preprocessed.head()
# Out:
#    log_price  EngineV  Mileage  ...  Engine Type_Other  Engine Type_Petrol  Registration_yes
# 0   8.342840      2.0      277  ...                  0                   1                 1
# 1   8.974618      2.9      427  ...                  0                   0                 1
# 2   9.495519      5.0      358  ...                  0                   0                 1
# 3  10.043249      4.2      240  ...                  0                   1                 1
# 4   9.814656      2.0      120  ...                  0                   1                 1
#
# [5 rows x 18 columns]

# %% [markdown]
# # ***`*Linear regression model*`***

# %%
targets = data_preprocessed['log_price']
inputs = data_preprocessed.drop(['log_price'],axis = 1)

# %% [markdown]
# scale data

# %%
  from sklearn.preprocessing import StandardScaler
  scaler = StandardScaler()
  scaler.fit(inputs)
  inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(inputs_scaled,targets,test_size = 0.2,random_state = 365)

# %% [markdown]
# create regression

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel('Targets(y_train)')
plt.ylabel('Predictions(y_hat)')
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %% [markdown]
# residual plot (residula is the diffrenece between the target and the prediction)
# its normally distributed which actually point towards normallity assumption

# %% [markdown]
# but there is a much longer tail in the left negative side which mean the y_train and y_hat for some observations is much lower than the mean this implays that those predication tend to overestimate the targets and vice versa

# %%
sns.distplot(y_train-y_hat)
plt.show()
# Out:
# <ipython-input-80-dbd53e7773a7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train-y_hat)

# %%
reg.score(x_train,y_train)
# Out:
# 0.744996578792662

# %%
reg.intercept_
# Out:
# 9.415239458021299

# %%
reg_summary = pd.DataFrame(inputs.columns.values,columns = ['Features'])
reg_summary['weights']=reg.coef_
reg_summary
# Out:
#                Features   weights
# 0               EngineV  0.209035
# 1               Mileage -0.448713
# 2             Brand_BMW  0.014250
# 3   Brand_Mercedes-Benz  0.012882
# 4      Brand_Mitsubishi -0.140552
# 5         Brand_Renault -0.179909
# 6          Brand_Toyota -0.060550
# 7      Brand_Volkswagen -0.089924
# 8            Body_hatch -0.145469
# 9            Body_other -0.101444
# 10           Body_sedan -0.200630
# 11           Body_vagon -0.129887
# 12             Body_van -0.168597
# 13      Engine Type_Gas -0.121490
# 14    Engine Type_Other -0.033368
# 15   Engine Type_Petrol -0.146909
# 16     Registration_yes  0.320473

# %% [markdown]
# # **`testing`**

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test,y_hat_test,alpha = 0.2)
plt.xlabel('Targets(y_test)')
plt.ylabel('Predictions(y_hat_test)')
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()
